# %% [markdown]
# # QwQ-32B
# ## ☘ 运行资源
# - 该项目基于**2张**国产异构加速卡AI，dtk24.04.3 加速卡驱动进行适配
#
# ## 🎀 使用说明：
# - 执行下方单元格代码启动服务 `!sh start.sh`
# - 看到日志打印出(服务启动会打印较多加载信息，请稍等待3~4分钟)：
#   ```shell
#     INFO:     Application startup complete.
#     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
#   ```
#   则说明服务已经启动
#
# - **模型部署：** 若在【模型部署】板块使用镜像部署私有服务，请加参数 `--mode prod` (`--mode`在 Notebook 时默认为 `dev`)，使用如下命令部署：
#   `sh /root/start.sh --mode prod`

# %%
# 执行启动服务
# !sh start.sh
# Out:
# INFO 04-16 10:28:37 api_server.py:549] vLLM API server version 0.6.2
# INFO 04-16 10:28:37 api_server.py:164] Multiprocessing frontend to use ipc:///tmp/cf8f993b-c17c-4861-bea8-b51009932e83 for IPC Path.
# INFO 04-16 10:28:37 api_server.py:177] Started engine process with PID 2664
# INFO 04-16 10:28:37 config.py:908] Defaulting to use mp for distributed inference
# INFO 04-16 10:28:37 config.py:937] Disabled the custom all-reduce kernel because it is not supported on hcus.
# INFO 04-16 10:28:47 config.py:908] Defaulting to use mp for distributed inference
# INFO 04-16 10:28:47 config.py:937] Disabled the custom all-reduce kernel because it is not supported on hcus.
# INFO 04-16 10:28:48 custom_cache_manager.py:17] Setting Triton cache manager to: vllm.triton_utils.custom_cache_manager:CustomCacheManager
# INFO 04-16 10:28:48 selector.py:121] Using ROCmFlashAttention backend.
# INFO 04-16 10:28:58 utils.py:996] Found nccl from library librccl.so.1
# ...

# %% [markdown]
# - 当上述信息出现时,通过控制台【自定义服务】设置端口<font color="blue">**8000**</font>
# <img src="./assets/setp.png" width="800" height="300" alt="dosc">
#
# - **再次点击**【自定义服务】即可跳转获取域名**链接地址**（注：此时打不开web页面）
# - <font color="red">**注意：跳转后位主域名地址，需要配合添加子路由地址，具体方法见如下功能介绍部分**</font>

# %% [markdown]
# ### 🌲 功能介绍
# **可用的主要路由地址如下：**
# - 路由地址: `/v1/models`, 请求方法: GET
# - 路由地址: `/v1/chat/completions`, 请求方法: POST
# - 路由地址: `/v1/completions`, 请求方法: POST
#
# <font color="green">**更多路由地址可通过/docs路由访问FastAPI网页查看**</font>
# - **路由方法，例如**：
# - 通过自定义服务浏览器跳转的网址是 `https://c-xxxxxxxxxx.ksai.scnet.cn:58043`，会自动重定向到 `/docs`：
# - `https://c-xxxxxxxxxx.ksai.scnet.cn:58043/docs` , 如下所示：
#
# <img src="./assets/route.png" width="800" height="400" alt="dosc">
#
#
# ## 🍐API 服务请求方法示例
# 这里展示在FastAPI进行 curl API 请求，同样，可以使用 Postman 等工具

# %% [markdown]
# - `/v1/chat/completions`
# > 完整 API 请求地址：`https://c-xxxxxxxxxx.ksai.scnet.cn:58043/v1/chat/completions`
# >
# > 模型路径：`/root/public_data/model/admin/Qwen/QwQ-32B`

# %% [markdown]
# <img src="./assets/chat.png" width="800" height="400" alt="dosc">
#
# **发起请求**
#
# 请求示例：
# ```json
# {
# "messages": [
#     {
#       "role": "system",
#       "content": "你是一位知识丰富、友好的助手，可以帮用户解答各方面的知识和问题。请提供清晰、准确和简短的答案。保持回应礼貌、吸引人、切中要害。不要中英文混合回答。",
#       "name": "system"
#     },
#     {
#       "role": "user",
#       "content": "请问1.25和1.1哪个更大，请说明理由",
#       "name": "user"
#     }
#   ],
#   "model": "/root/public_data/model/admin/Qwen/QwQ-32B",
#   "temperature": 0.7,
#   "top_p": 0.9,
#   "max_tokens": 1024
# }
# ```
#
# <img src="./assets/execut.png" width="750" height="300" alt="dosc">
#
# **请求返回**
#
# <img src="./assets/response.png" width="750" height="300" alt="dosc">

# %% [markdown]
# ![image.png](attachment:cc1c9032-07da-4640-9049-d7b26cafee68.png)
